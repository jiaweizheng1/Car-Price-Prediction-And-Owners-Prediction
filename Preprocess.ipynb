# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
df = df.set_index('name')

# %%
catg = df[['year','fuel','seller_type','transmission','owner']]
for i in catg.columns:
    print(catg[i].value_counts())
# Out:
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: year, dtype: int64
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
df['owner'] = df['owner'].apply(lambda x:0 if x == "First Owner" else 1).astype(int) # 0 First owner means 
#new car 1 second and above means used. This definition seems clear and more simplified

# %%
df['year'] = df['year'].apply(lambda x:0 if x<2000 else 
                              (1 if x>=2000 and x<=2005 else(
                               2 if x>=2006 and x<=2010 else(
                               3 if x>=2011 and x<=2015 else 4)))).astype(int)
#0 Any car from before 2000 1 2000-2005 2 2006-2010 3 2011-2015 4 Any car after 2015
#Keep year as numeric by applying one-label encoding due to its ordinal nature

# %%
df
# Out:
#                                      year  selling_price  km_driven    fuel  \
# name
# Maruti 800 AC                           2          60000      70000  Petrol
# Maruti Wagon R LXI Minor                2         135000      50000  Petrol
# Hyundai Verna 1.6 SX                    3         600000     100000  Diesel
# Datsun RediGO T Option                  4         250000      46000  Petrol
# Honda Amaze VX i-DTEC                   3         450000     141000  Diesel
# ...                                   ...            ...        ...     ...
# Hyundai i20 Magna 1.4 CRDi (Diesel)     3         409999      80000  Diesel
# Hyundai i20 Magna 1.4 CRDi              3         409999      80000  Diesel
# Maruti 800 AC BSIII                     2         110000      83000  Petrol
# Hyundai Creta 1.6 CRDi SX Option        4         865000      90000  Diesel
# Renault KWID RXT                        4         225000      40000  Petrol
#
# ...

# %%
df['fuel'] = df['fuel'].apply(lambda x:'Petrol' if x == 'Petrol' else ('Diesel' if x == 'Diesel' else 'Other'))

# %%
df = pd.get_dummies(df, columns = ['fuel','seller_type','transmission'])

# %%
df
# Out:
#                                      year  selling_price  km_driven  owner  \
# name
# Maruti 800 AC                           2          60000      70000      0
# Maruti Wagon R LXI Minor                2         135000      50000      0
# Hyundai Verna 1.6 SX                    3         600000     100000      0
# Datsun RediGO T Option                  4         250000      46000      0
# Honda Amaze VX i-DTEC                   3         450000     141000      1
# ...                                   ...            ...        ...    ...
# Hyundai i20 Magna 1.4 CRDi (Diesel)     3         409999      80000      1
# Hyundai i20 Magna 1.4 CRDi              3         409999      80000      1
# Maruti 800 AC BSIII                     2         110000      83000      1
# Hyundai Creta 1.6 CRDi SX Option        4         865000      90000      0
# Renault KWID RXT                        4         225000      40000      0
#
# ...

# %%
df = df.drop(columns = ['fuel_Other','seller_type_Trustmark Dealer','transmission_Automatic'])

# %%
owner = df.pop('owner')
df.insert(0,'owner',owner)

# %%
df.to_csv('Cars.csv')

# %%
df
# Out:
#                                      owner  year  selling_price  km_driven  \
# name
# Maruti 800 AC                            0     2          60000      70000
# Maruti Wagon R LXI Minor                 0     2         135000      50000
# Hyundai Verna 1.6 SX                     0     3         600000     100000
# Datsun RediGO T Option                   0     4         250000      46000
# Honda Amaze VX i-DTEC                    1     3         450000     141000
# ...                                    ...   ...            ...        ...
# Hyundai i20 Magna 1.4 CRDi (Diesel)      1     3         409999      80000
# Hyundai i20 Magna 1.4 CRDi               1     3         409999      80000
# Maruti 800 AC BSIII                      1     2         110000      83000
# Hyundai Creta 1.6 CRDi SX Option         0     4         865000      90000
# Renault KWID RXT                         0     4         225000      40000
#
# ...
